# %%
#import the Python libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#read the dataset
sns.set(style="whitegrid")
data = pd.read_csv("INR=X.csv")
print(data.head())
# Out:
#          Date       Open       High        Low      Close  Adj Close  Volume
# 0  2022-12-05  81.422501  81.894997  81.193497  81.422501  81.422501       0
# 1  2022-12-06  81.899002  82.600197  81.691498  81.899002  81.899002       0
# 2  2022-12-07  82.372200  82.738503  82.204597  82.372200  82.372200       0
# 3  2022-12-08  82.253502  82.538803  82.237000  82.253502  82.253502       0
# 4  2022-12-09  82.279198  82.508301  82.073997  82.279198  82.279198       0

# %%
#Data Visuliasation of the target value ‘close’ which needs to be predicted
plt.figure(figsize=(10, 4))
plt.title("INR - USD Exchange Rate")
plt.xlabel("Date")
plt.ylabel("Close")
plt.plot(data["Close"])
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
data = pd.read_csv("INR=X.csv")

# Select only numeric columns for correlation calculation
numeric_data = data.select_dtypes(include=[np.number])

# Display correlation matrix
print(numeric_data.corr())

# Create and display a heatmap of the correlation matrix
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.show()
# Out:
#                Open      High       Low     Close  Adj Close  Volume
# Open       1.000000  0.929740  0.922501  1.000000   1.000000     NaN
# High       0.929740  1.000000  0.902768  0.929740   0.929740     NaN
# Low        0.922501  0.902768  1.000000  0.922501   0.922501     NaN
# Close      1.000000  0.929740  0.922501  1.000000   1.000000     NaN
# Adj Close  1.000000  0.929740  0.922501  1.000000   1.000000     NaN
# Volume          NaN       NaN       NaN       NaN        NaN     NaN

# %%
#Storing the specific columns in x, y and converting it to numpy array
x = data[["Open", "High", "Low"]]
y = data["Close"]
x = x.to_numpy()
y = y.to_numpy()
y = y.reshape(-1, 1)

# %%
#Split the dataset and train a model using Decision Tree Regression model
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
#predicted values of currency exchange rates of INR for the next 5 days
data = pd.DataFrame(data={"Predicted Rate": ypred.flatten()})
print(data.head())
# Out:
#    Predicted Rate
# 0       83.194199
# 1       83.029404
# 2       82.677002
# 3       82.018402
# 4       81.852303
